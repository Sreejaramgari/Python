# %%
#importing required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install pandas

# %%
pip install matplotlib.pyplot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("Housing.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv("Housing.csv")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv("Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    str
#  6   guestroom         545 non-null    str
#  7   basement          545 non-null    str
#  8   hotwaterheating   545 non-null    str
#  9   airconditioning   545 non-null    str
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    str
#  12  furnishingstatus  545 non-null    str
# dtypes: int64(6), str(7)
# memory usage: 55.5 KB

# %%
#getting columns name
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='str')

# %%
#statistical description about numeric colums
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
#categorical column statistical values
df.describe(exclude = 'int')
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %%
#head():returns top 5 values
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
#for particular colum
df['area']
# Out:
# 0      7420
# 1      8960
# 2      9960
# 3      7500
# 4      7420
#        ...
# 540    3000
# 541    2400
# 542    3620
# 543    2910
# 544    3850
# Name: area, Length: 545, dtype: int64

# %%
#for multiple colums
df[['area','price']]
# Out:
#      area     price
# 0    7420  13300000
# 1    8960  12250000
# 2    9960  12250000
# 3    7500  12215000
# 4    7420  11410000
# ..    ...       ...
# 540  3000   1820000
# 541  2400   1767150
# 542  3620   1750000
# 543  2910   1750000
# 544  3850   1750000
#
# [545 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='str')

# %%
categorical_values = df[['mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning','prefarea', 'furnishingstatus']]
categorical_values
# Out:
#     mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# 0        yes        no       no              no             yes      yes
# 1        yes        no       no              no             yes       no
# 2        yes        no      yes              no              no      yes
# 3        yes        no      yes              no             yes      yes
# 4        yes       yes      yes              no             yes       no
# ..       ...       ...      ...             ...             ...      ...
# 540      yes        no      yes              no              no       no
# 541       no        no       no              no              no       no
# 542      yes        no       no              no              no       no
# 543       no        no       no              no              no       no
# 544      yes        no       no              no              no       no
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# ...

# %%
#replacing categorical values like yes or no with 1 ans 0
map_values = {'no': 0, 'yes' : 1}
df['mainroad'] = df['mainroad'].replace(map_values)
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3        1        no       no
# 1  12250000  8960         4          4        4        1        no       no
# 2  12250000  9960         3          2        2        1        no      yes
# 3  12215000  7500         4          2        2        1        no      yes
# 4  11410000  7420         4          1        2        1       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
map_values = {'no': 0, 'yes' : 1}
df['mainroad'] = df['mainroad'].replace(map_values)
df['guestroom'] = df['guestroom'].replace(map_values)
df['basement'] = df['basement'].replace(map_values)
df['hotwaterheating'] = df['hotwaterheating'].replace(map_values)
df['airconditioning'] = df['airconditioning'].replace(map_values)
df['prefarea'] = df['prefarea'].replace(map_values)
df['furnishingstatus'] = df['furnishingstatus'].replace({'furnished':2, 'semi-furnished':1, 'unfurnished':3})
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3        1         0        0
# 1  12250000  8960         4          4        4        1         0        0
# 2  12250000  9960         3          2        2        1         0        1
# 3  12215000  7500         4          2        2        1         0        1
# 4  11410000  7420         4          1        2        1         1        1
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0               0               1        2        1                2
# 1               0               1        3        0                2
# 2               0               0        2        1                1
# 3               0               1        3        1                2
# 4               0               1        2        0                2

# %%
#unique:what values present in column
df.furnishingstatus.unique()
# Out:
# <StringArray>
# ['furnished', 'semi-furnished', 'unfurnished']
# Length: 3, dtype: str

# %%
#value_counts:prints how may values present in cols
df.furnishingstatus.value_counts()
# Out:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %%
df.mainrosd = df.mainroad.astype('int')
# Out:
# C:\Users\sreej\AppData\Local\Temp\ipykernel_12656\1793341141.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.mainrosd = df.mainroad.astype('int')

# %%
import pandas as pd

# %%
df = pd.read_csv("Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    str
#  6   guestroom         545 non-null    str
#  7   basement          545 non-null    str
#  8   hotwaterheating   545 non-null    str
#  9   airconditioning   545 non-null    str
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    str
#  12  furnishingstatus  545 non-null    str
# dtypes: int64(6), str(7)
# memory usage: 55.5 KB

# %%
df.mainroad = df.mainroad.astype('int')
df.guestroom = df.guestroom.astype('int')
df.basement = df.basement.astype('int')
df.hotwaterheating = df.hotwaterheating.astype('int')
df.airconditioning = df.airconditioning.astype('int')
df.prefarea = df.prefarea.astype('int')
df.furnishingstatus  = df.furnishingstatus.astype('int')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    int64
#  6   guestroom         545 non-null    int64
#  7   basement          545 non-null    int64
#  8   hotwaterheating   545 non-null    int64
#  9   airconditioning   545 non-null    int64
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    int64
#  12  furnishingstatus  545 non-null    int64
# dtypes: int64(13)
# memory usage: 55.5 KB

# %%
#data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# data visualization
plt.figure(figsize=(8, 8))
sns.heatmap(data=df, annot=True)
plt.show()

# %%
#bar plot
plt.figure(figsize =(12,8))
sns.barplot(data= df[[ 'bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus']])
plt.show()

# %%
plt.figure(figsize =(6,6))
sns.barplot(data= df[['price','area']])
plt.show()

# %%
#line plot
plt.figure(figsize = (12, 6))
sns.lineplot(data = df, x='area',y='price')
plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.lineplot(data = df, x='area', y='price',hue='bedrooms')
plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.lineplot(data = df.loc[0 : 50], x='area', y='price',hue='mainroad')
plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.lineplot(data = df.loc[100:200], x='area', y='price',hue='mainroad')
plt.show()

# %%
#scatter plot
plt.figure(figsize = (12, 6))
sns.scatterplot(data = df, x='area', y='price',hue='mainroad')
plt.show()

# %%
df.

# %%
#kde plot
plt.figure(figsize = (12, 6))
sns.kdeplot(data = df, x='area', y='price',hue='mainroad')
plt.show()

# %%
#scatter plot
plt.figure(figsize = (8,5))
sns.scatterplot(data = df, x='bedrooms', y='airconditioning',hue='mainroad')
plt.show()

# %%
#kde plot
plt.figure(figsize = (12, 6))
sns.kdeplot(data = df, x='area', y='price')
plt.show()

# %%
#kde plot
plt.figure(figsize = (12, 6))
sns.kdeplot(data = df, x='area')
plt.show()

# %%
#kde plot
plt.figure(figsize = (12, 6))
sns.kdeplot(data = df, x='area')
plt.grid(True)
plt.show()

# %%
#kde plot
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
#scatter plot
plt.figure(figsize = (8,5))
sns.scatterplot(data = df, x='hotwaterheating', y='airconditioning')
plt.show()

# %%
#countplot
sns.countplot(data = df)
plt.show()

# %%
sns.countplot(data = df, x = 'mainroad', hue = 'parking')
plt.show()

# %%
#yes = 1 more air conditioning towards main road no - 0
sns.countplot(data = df, x = 'mainroad', hue = 'airconditioning')
plt.show()

# %%
#yes = 1 more air conditioning towards main road no - 0
sns.countplot(data = df, x ='bedrooms', hue = 'airconditioning')
plt.show()
